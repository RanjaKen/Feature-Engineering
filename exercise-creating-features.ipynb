# %% [markdown]
# **This notebook is an exercise in the [Feature Engineering](https://www.kaggle.com/learn/feature-engineering) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/creating-features).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise you'll start developing the features you identified in Exercise 2 as having the most potential. As you work through this exercise, you might take a moment to look at the data documentation again and consider whether the features we're creating make sense from a real-world perspective, and whether there are any useful combinations that stand out to you.
#
# Run this cell to set everything up!

# %%
# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.feature_engineering_new.ex3 import *

import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor


def score_dataset(X, y, model=XGBRegressor()):
    # Label encoding for categoricals
    for colname in X.select_dtypes(["category", "object"]):
        X[colname], _ = X[colname].factorize()
    # Metric for Housing competition is RMSLE (Root Mean Squared Log Error)
    score = cross_val_score(
        model, X, y, cv=5, scoring="neg_mean_squared_log_error",
    )
    score = -1 * score.mean()
    score = np.sqrt(score)
    return score


# Prepare data
df = pd.read_csv("../input/fe-course-data/ames.csv")
X = df.copy()
y = X.pop("SalePrice")

# %% [markdown]
# -------------------------------------------------------------------------------
#
# Let's start with a few mathematical combinations. We'll focus on features describing areas -- having the same units (square-feet) makes it easy to combine them in sensible ways. Since we're using XGBoost (a tree-based model), we'll focus on ratios and sums.
#
# # 1) Create Mathematical Transforms
#
# Create the following features:
#
# - `LivLotRatio`: the ratio of `GrLivArea` to `LotArea`
# - `Spaciousness`: the sum of `FirstFlrSF` and `SecondFlrSF` divided by `TotRmsAbvGrd`
# - `TotalOutsideSF`: the sum of `WoodDeckSF`, `OpenPorchSF`, `EnclosedPorch`, `Threeseasonporch`, and `ScreenPorch`

# %%
# YOUR CODE HERE
X_1 = pd.DataFrame()  # dataframe to hold new features

X_1["LivLotRatio"] = df.GrLivArea / df.LotArea
X_1["Spaciousness"] = (df.FirstFlrSF + df.SecondFlrSF)/ df.TotRmsAbvGrd
X_1["TotalOutsideSF"] = df.WoodDeckSF + df.OpenPorchSF + df.EnclosedPorch + df.Threeseasonporch + df.ScreenPorch


# Check your answer
q_1.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_1.hint()
#q_1.solution()

# %% [markdown]
# -------------------------------------------------------------------------------
#
# If you've discovered an interaction effect between a numeric feature and a categorical feature, you might want to model it explicitly using a one-hot encoding, like so:
#
# ```
# # One-hot encode Categorical feature, adding a column prefix "Cat"
# X_new = pd.get_dummies(df.Categorical, prefix="Cat")
#
# # Multiply row-by-row
# X_new = X_new.mul(df.Continuous, axis=0)
#
# # Join the new features to the feature set
# X = X.join(X_new)
# ```
#
# # 2) Interaction with a Categorical
#
# We discovered an interaction between `BldgType` and `GrLivArea` in Exercise 2. Now create their interaction features.

# %%
# YOUR CODE HERE
# One-hot encode BldgType. Use `prefix="Bldg"` in `get_dummies`
X_2 = pd.get_dummies(df.BldgType, prefix="Bldg")
# Multiply
X_2 = X_2.mul(df.GrLivArea, axis=0)


# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
q_2.hint()
#q_2.solution()
# Out:
# Hint: Your code should look something like:
# ```python
# X_2 = pd.get_dummies(____, prefix="Bldg")
# X_2 = X_2.mul(____, axis=0)
# ```

# %% [markdown]
# # 3) Count Feature
#
# Let's try creating a feature that describes how many kinds of outdoor areas a dwelling has. Create a feature `PorchTypes` that counts how many of the following are greater than 0.0:
#
# ```
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# Threeseasonporch
# ScreenPorch
# ```

# %%
X_3 = pd.DataFrame()

# YOUR CODE HERE
X_3["PorchTypes"] = andrana


# Check your answer
q_3.check()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_30/542422134.py in ?()
#       4 X_3["PorchTypes"] = ____
#       5
#       6
#       7 # Check your answer
# ----> 8 q_3.check()
#
# /opt/conda/lib/python3.10/site-packages/learntools/core/problem_view.py in ?(self, *args, **kwargs)
#      21     @functools.wraps(method)
#      22     def wrapped(self, *args, **kwargs):
#      23         self.interactions[method.__name__] += 1
# ---> 24         return method(self, *args, **kwargs)
#
# /opt/conda/lib/python3.10/site-packages/learntools/core/problem_view.py in ?(*args, **kwargs)
#      13     @functools.wraps(fn)
#      14     def wrapped(*args, **kwargs):
# ---> 15         res = fn(*args, **kwargs)
#      16         display(res)
#      17         # Don't propagate the return to avoid double printing.
#
# /opt/conda/lib/python3.10/site-packages/learntools/core/problem_view.py in ?(self)
#     106                 self._track_check(tracking.OutcomeType.FAIL,
#     107                     failureMessage=str(e),
#     108                     )
#     109             return TestFailure(str(e))
# --> 110         except Uncheckable as e:
#     111             msg = str(e) or 'Sorry, no auto-checking available for this question.'
#     112             self._track_check(tracking.OutcomeType.EXCEPTION,
#     113                 failureMessage=msg,
#
# /opt/conda/lib/python3.10/site-packages/learntools/feature_engineering_new/ex3.py in ?(self, X_3)
#     123         ), f"Columns are incorrect. You should have {list(X_solution.columns)}. You gave {list(X_3.columns)}"
#     124         assert sorted(X_solution.columns) == sorted(
#     125             X_3.columns
#     126         ), f"Columns are incorrect. You should have {list(X_solution.columns)}. You gave {list(X_3.columns)}"
# --> 127         assert (X_solution == X_3).all().all()
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/ops/common.py in ?(self, other)
#      72                     return NotImplemented
#      73
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py in ?(self, other)
#      38     @unpack_zerodim_and_defer("__eq__")
#      39     def __eq__(self, other):
# ---> 40         return self._cmp_method(other, operator.eq)
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, other, op)
#    7894     def _cmp_method(self, other, op):
#    7895         axis: Literal[1] = 1  # only relevant for Series other case
#    7896
# -> 7897         self, other = self._align_for_op(other, axis, flex=False, level=None)
#    7898
#    7899         # See GH#4537 for discussion of scalar op behavior
#    7900         new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, other, axis, flex, level)
#    8192                     left, right = left.align(
#    8193                         right, join="outer", level=level, copy=False
#    8194                     )
#    8195                 else:
# -> 8196                     raise ValueError(
#    8197                         "Can only compare identically-labeled (both index and columns) "
#    8198                         "DataFrame objects"
#    8199                     )
#
# ValueError: Can only compare identically-labeled (both index and columns) DataFrame objects

# %%
# Lines below will give you a hint or solution code
q_3.hint()
#q_3.solution()
# Out:
# Hint: Your code should look someting like:
# ```python
# X_3 = pd.DataFrame()
#
# X_3["PorchTypes"] = df[[
#     ____,
#     ____,
#     ____,
#     ____,
#     ____,
# ]].____.sum(axis=1)
# ```

# %% [markdown]
# # 4) Break Down a Categorical Feature
#
# `MSSubClass` describes the type of a dwelling:

# %%
df.MSSubClass.unique()
# Out:
# array(['One_Story_1946_and_Newer_All_Styles', 'Two_Story_1946_and_Newer',
#        'One_Story_PUD_1946_and_Newer',
#        'One_and_Half_Story_Finished_All_Ages', 'Split_Foyer',
#        'Two_Story_PUD_1946_and_Newer', 'Split_or_Multilevel',
#        'One_Story_1945_and_Older', 'Duplex_All_Styles_and_Ages',
#        'Two_Family_conversion_All_Styles_and_Ages',
#        'One_and_Half_Story_Unfinished_All_Ages',
#        'Two_Story_1945_and_Older', 'Two_and_Half_Story_All_Ages',
#        'One_Story_with_Finished_Attic_All_Ages',
#        'PUD_Multilevel_Split_Level_Foyer',
#        'One_and_Half_Story_PUD_All_Ages'], dtype=object)

# %% [markdown]
# You can see that there is a more general categorization described (roughly) by the first word of each category. Create a feature containing only these first words by splitting `MSSubClass` at the first underscore `_`. (Hint: In the `split` method use an argument `n=1`.)

# %%
X_4 = pd.DataFrame()

# YOUR CODE HERE
____

# Check your answer
q_4.check()
# Out:
# Incorrect: Columns are incorrect. You should have ['MSClass']. You gave []

# %%
# Lines below will give you a hint or solution code
#q_4.hint()
#q_4.solution()

# %% [markdown]
# # 5) Use a Grouped Transform
#
# The value of a home often depends on how it compares to typical homes in its neighborhood. Create a feature `MedNhbdArea` that describes the *median* of `GrLivArea` grouped on `Neighborhood`.

# %%
X_5 = pd.DataFrame()

# YOUR CODE HERE
X_5["MedNhbdArea"] = ____

# Check your answer
q_5.check()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 7
#       4 X_5["MedNhbdArea"] = ____
#       6 # Check your answer
# ----> 7 q_5.check()
#
# File /opt/conda/lib/python3.10/site-packages/learntools/core/problem_view.py:24, in record.<locals>.wrapped(self, *args, **kwargs)
#      21 @functools.wraps(method)
#      22 def wrapped(self, *args, **kwargs):
#      23     self.interactions[method.__name__] += 1
# ---> 24     return method(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/learntools/core/problem_view.py:15, in displayer.<locals>.wrapped(*args, **kwargs)
#      13 @functools.wraps(fn)
#      14 def wrapped(*args, **kwargs):
# ---> 15     res = fn(*args, **kwargs)
#      16     display(res)
#
# File /opt/conda/lib/python3.10/site-packages/learntools/core/problem_view.py:91, in ProblemView.check(self)
#      89         args = ()
#      90     self.problem.check_whether_attempted(*args)
# ---> 91     self.problem.check(*args)
#      92 except NotAttempted as e:
#      93     self._track_check(tracking.OutcomeType.UNATTEMPTED)
#
# File /opt/conda/lib/python3.10/site-packages/learntools/feature_engineering_new/ex3.py:189, in Q5.check(self, X_5)
#     183 assert len(X_solution.columns) == len(
#     184     X_5.columns
#     185 ), f"Columns are incorrect. You should have {list(X_solution.columns)}. You gave {list(X_5.columns)}"
#     186 assert sorted(X_solution.columns) == sorted(
#     187     X_5.columns
#     188 ), f"Columns are incorrect. You should have {list(X_solution.columns)}. You gave {list(X_5.columns)}"
# --> 189 assert (X_solution.MedNhbdArea == X_5.MedNhbdArea).all()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:6114, in Series._cmp_method(self, other, op)
#    6111 res_name = ops.get_op_result_name(self, other)
#    6113 if isinstance(other, Series) and not self._indexed_same(other):
# -> 6114     raise ValueError("Can only compare identically-labeled Series objects")
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#
# ValueError: Can only compare identically-labeled Series objects

# %%
# Lines below will give you a hint or solution code
#q_5.hint()
#q_5.solution()

# %% [markdown]
# Now you've made your first new feature set! If you like, you can run the cell below to score the model with all of your new features added:

# %%
X_new = X.join([X_1, X_2, X_3, X_4, X_5])
score_dataset(X_new, y)

# %% [markdown]
# # Keep Going #
#
# [**Untangle spatial relationships**](https://www.kaggle.com/ryanholbrook/clustering-with-k-means) by adding cluster labels to your dataset.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/feature-engineering/discussion) to chat with other learners.*
